# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import linear_model
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler

# %%
data = pd.read_csv("C:/Users/hp/Documents/energydata_complete_122044.csv")

data.head(5)
# Out:
#                   date  Appliances  lights     T1       RH_1    T2       RH_2  \
# 0  2016-01-11 17:00:00          60      30  19.89  47.596667  19.2  44.790000
# 1  2016-01-11 17:10:00          60      30  19.89  46.693333  19.2  44.722500
# 2  2016-01-11 17:20:00          50      30  19.89  46.300000  19.2  44.626667
# 3  2016-01-11 17:30:00          50      40  19.89  46.066667  19.2  44.590000
# 4  2016-01-11 17:40:00          60      40  19.89  46.333333  19.2  44.530000
#
#       T3       RH_3         T4  ...         T9   RH_9     T_out  Press_mm_hg  \
# 0  19.79  44.730000  19.000000  ...  17.033333  45.53  6.600000        733.5
# 1  19.79  44.790000  19.000000  ...  17.066667  45.56  6.483333        733.6
# 2  19.79  44.933333  18.926667  ...  17.000000  45.50  6.366667        733.7
# 3  19.79  45.000000  18.890000  ...  17.000000  45.40  6.250000        733.8
# 4  19.79  45.000000  18.890000  ...  17.000000  45.40  6.133333        733.9
#
# ...

# %%
#checkin for sum of null values in dataset
data.isna().sum()

# %%
data.columns
# Out:
# Index(['Appliances', 'lights', 'T1', 'RH_1', 'T2', 'RH_2', 'T3', 'RH_3', 'T4',
#        'RH_4', 'T5', 'RH_5', 'T6', 'RH_6', 'T7', 'RH_7', 'T8', 'RH_8', 'T9',
#        'RH_9', 'T_out', 'Press_mm_hg', 'RH_out', 'Windspeed', 'Visibility',
#        'Tdewpoint'],
#       dtype='object')

# %%
data = data.drop(columns=['date', 'rv1', 'rv2'])

from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

# %%
# X = living-room temp, Y_ = outdoor temp
X_ = data[['T2']]  #Independent variables
Y_ = data['T6']  #Target variables

# %%
#Model to be used

Reg = linear_model.LinearRegression()

# %%
#Train model
Reg.fit(X_, Y_)
# Out:
# LinearRegression()

# %%
Reg.score(X_, Y_)
# Out:
# 0.6418990830855493

# %%
predict = Reg.predict(X_)
predict
# Out:
# array([ 5.37165597,  5.37165597,  5.37165597, ..., 19.67562202,
#        19.19818742, 18.86506395])

# %%
from sklearn.metrics import mean_squared_error

# Computing RMSE
MSE = mean_squared_error(Y_, predict)
RMSE = np.sqrt(MSE)

# Print result rounded to 3 decimal places
print(f"Root Mean Squared Error is: { round(RMSE, 3)}")
# Out:
# Root Mean Squared Error is: 3.644

# %%
data.columns
# Out:
# Index(['Appliances', 'lights', 'T1', 'RH_1', 'T2', 'RH_2', 'T3', 'RH_3', 'T4',
#        'RH_4', 'T5', 'RH_5', 'T6', 'RH_6', 'T7', 'RH_7', 'T8', 'RH_8', 'T9',
#        'RH_9', 'T_out', 'Press_mm_hg', 'RH_out', 'Windspeed', 'Visibility',
#        'Tdewpoint'],
#       dtype='object')

# %%
data = data.drop(columns=["lights"])

# %%
X = data.drop(columns="Appliances")
Y = data["Appliances"]

# %%
# Train-test split (70-30)
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.3, random_state=42)

# %%
scale = MinMaxScaler()
X_train_scaled = scale.fit_transform(X_train)
X_test_scaled = scale.transform(X_test)

# %%
Reg_ = linear_model.LinearRegression()
Reg_.fit(X_train_scaled, y_train)
# Out:
# LinearRegression()

# %%
train_predict = Reg_.predict(X_train_scaled)

from sklearn.metrics import mean_absolute_error
# Mean Absolute Error
MAE = mean_absolute_error(y_train, train_predict)
print(f"The Mean Absolute Error (Training Set) is: {round(MAE, 3)}")
# Out:
# The Mean Absolute Error (Training Set) is: 53.745

# %%
RMSE_train = np.sqrt(mean_squared_error(y_train, train_predict))
print(f"The Training RMSE is; {RMSE_train:.3f}")
# Out:
# The Training RMSE is; 95.217

# %%
from sklearn.metrics import mean_absolute_error

# Predict on the test set
test_pred = Reg_.predict(X_test_scaled)

# Computing MAE
mae_test = mean_absolute_error(y_test, test_pred)

print(f"The Mean Absolute Error (test set) is; {round(mae_test, 3)}")
# Out:
# The Mean Absolute Error (test set) is; 53.639

# %%
rmse_test = np.sqrt(mean_squared_error(y_test, test_pred))
print(f"The Training RMSE is: {rmse_test:.3f}")
# Out:
# The Training RMSE is: 93.624

# %%
#checking for possible overfitting
from sklearn.metrics import r2_score

train_r2 = r2_score(y_train, train_predict)
test_r2 = r2_score(y_test, test_pred)

# %%
print("Train R² Score:", round(train_r2, 3))
print("Test R² Score:", round(test_r2, 3))
# Out:
# Train R² Score: 0.145
# Test R² Score: 0.149

# %%
from sklearn.linear_model import Ridge

# %%
ridge = Ridge()  # default alpha=1.0
ridge.fit(X_train, y_train)

y_pred_test = ridge.predict(X_test)

rmse_test = np.sqrt(mean_squared_error(y_test, y_pred_test))
print(f"The Test RMSE (Ridge) is:", rmse_test)
# Out:
# The Test RMSE (Ridge) is: 93.62388902547347

# %%
from sklearn.linear_model import Lasso

# Assume X_train, y_train are already defined

lasso = Lasso()  # default alpha=1.0
lasso.fit(X_train, y_train)

# Get the coefficients (feature weights)
coefficients = lasso.coef_

# Count how many are non-zero
non_zero_count = sum(coeff != 0 for coeff in coefficients)

print("Number of features with non-zero weights:", non_zero_count)
# Out:
# Number of features with non-zero weights: 19

# %%
# Predict on test set
y_pred_test = lasso.predict(X_test)

# Calculate RMSE
rmse_test = np.sqrt(mean_squared_error(y_test, y_pred_test))
print(f"The Test RMSE (Lasso) is:", rmse_test)
# Out:
# The Test RMSE (Lasso) is: 93.88149752694456
